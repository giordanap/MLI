# %%
import requests

# %%
page =requests.get('https://elcomercio.pe/') ## el codigo 200 que nuestro pedido ha sido un exito
page.content # aqui sale el codigo html, para convertirla a uno mas amigable como el html
# Out:
# b'<!DOCTYPE html><html lang="es"><head><script>(function (w, d, s, l, i) {\n    w[l] = w[l] || []\n    w[l].push({\n      \'gtm.start\': new Date().getTime(),\n      event: \'gtm.js\',\n    })\n    var f = d.getElementsByTagName(s)[0],\n      j = d.createElement(s),\n      dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'\n    j.async = true\n    j.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl\n    f.parentNode.insertBefore(j, f)\n  })(window, document, \'script\', \'dataLayer\', \'GTM-PFFL5R9\')</script><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><title>Noticias del Per\xc3\xba y el Mundo | Elecciones 2020 | Bolivia | Evo Morales | Congreso | Keiko Fujimori | Susel Paredes | Poder Judicial | Pico y Placa | Final Libertadores 2019 | Chile | Sebasti\xc3\xa1n Pi\xc3\xb1era | Alberto Fujimori | Mauricio Mulder | BCR | TC | Argentina | Cristina Kirchner | Edwin Donayre | Metropolitano | Martin Vizcarra | Donald Trump | Venezuela | Caso Odebrecht | #EstoyAlerta | Keiko Fujimori | APRA | Vladimiro Montesinos | Espa\xc3\xb1a vs Francia | Brasil vs Italia | Jos\xc3\xa9 P\xc3\xa9rez | Tribunal Constitucional | Luciana Leon | Casta\xc3\xb1eda Lossio | Alejandro Toledo | Christian Dominguez | Melisa Gonzales | Alan Garcia | Comisi\xc3\xb3n de Venecia | Salvador del Solar | Fornite | Selecci\xc3\xb3n peruana | Sunedu | Telesup | George Forsyth | Gabinete Ministerial | MEF | Venezolanos | Jorge Barata | Fuerza Popular | WWE | T\xc3\xada Mar\xc3\xada | Venezuela | Paolo Guerrero | Cesar Hinostroza | Poder Judicial | Champions League | Huawei | iPhone | PPK | Daniel Salaverry | Claudio Pizarro | Poder Judicial | FARC | Pedro Chavarry | Copa Libertadores | Esto es Guerra | OAS | Metro de Lima | Sismo | Ipsos | Neymar | Temblor | Terremoto | Facebook | Peajes | Google | Estados Unidos | Argentina | Ollanta Humala | Avengers | Espa\xc3\xb1a | Lima | Fonavi | SJL | Metropolitano | Brasil | Real Madrid | Cesar Villanueva | EVDLV | Copa Libertadores | Brasil | Mexico | Claudio Pizarro | AFP | M\xc3\xa9xico | Dragon Ball | Jos\xc3\xa9 Domingo Perez | Fuerza Popular | A\xc3\xb1o 2019 | AMLO | El Chapo | CTS | Sunat | FIFA | Espa\xc3\xb1a | ONPE | UFC | JNE | ONU |  #Notepases | Cristiano Ronaldo | Lionel Messi | Jefferson Farfan | Alianza Lima |  Mundial |  Copa Sudamericana | Real Madrid | Barcelona | Horoscopo |  Netflix | WWE | Facebook | Instagram | YouTube | WhatsApp |  Maps | Traductor | El Comercio Per\xc3\xba | El Comercio Per\xc3\xba</title><link rel="dns-prefetch" href="//ecoid.pe"/><link rel="dns-prefetch" href="//fonts.gstatic.com"/><link rel="dns-prefetch" href="//ajax.googleapis.com"/><link rel="dns-prefetch" href="//fonts.googleapis.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="stylesheet" href="/pf/resources/dist/elcomercio/css/style.css?d=386"/><link rel="shortcut icon" type="image/png" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/favicon.png?d=386"/><link rel="apple-touch-icon" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon.png?d=386"/><link rel="apple-touch-icon" sizes="76x76" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon-76x76.png?d=386"/><link rel="apple-touch-icon" sizes="120x120" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon-120x120.png?d=386"/><link rel="apple-touch-icon" sizes="144x144" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon-144x144.png?d=386"/><link rel="apple-touch-icon" sizes="152x152" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon-152x152.png?d=386"/><link rel="apple-touch-icon" sizes="180x180" href="https://elcomercio.pe/pf/resources/dist/elcomercio/images/apple-touch-icon-180x180.png?d=386"/><link rel="canonical" href="https://elcomercio.pe/"/><meta name="theme-col ...

# %%
# el beautiful soul te ayuda, te arma el arbol de hmtl
from bs4 import BeautifulSoup

# %%
content = BeautifulSoup(page.content, 'html.parser') #parser es el traductor q identifica las etiquetas
content  # contiene todo el html

# %%
content.find('footer') #encuentra etiquetas
# Out:
# <footer class=""><div class="flex flex-col p-30 bg-primary md:flex-row"><div class="flex-1 pr-20 pl-20 position-relative text-center md:text-left"><a class="footer__logo-container inline-block mb-15" href="/"><img alt="Logo de elcomercio" class="lazy w-full" data-src="/pf/resources/dist/elcomercio/images/logo.png?d=386" src=""/></a><address class="font-normal"><p class="text-sm line-h-md text-center md:text-left">Empresa Editora El Comercio</p><p class="text-sm line-h-md text-center md:text-left">Jr. Santa Rosa #300 Lima 1 Perú</p><p class="text-sm line-h-md text-center md:text-left">Copyright © Elcomercio.pe</p><p class="text-sm line-h-md text-center md:text-left">Grupo El Comercio - Todos los derechos reservados</p></address><div class="position-absolute bottom-0 hidden md:block"><img alt="Logo de Miembro del Grupo de Diarios de América" class="lazy mb-5" data-src="/pf/resources/assets/footer/logo-gda.png?d=386" src=""/><p class="text-sm line-h-sm">Miembro del Grupo de Diarios de América</p></div></div><div class="flex-1 pr-20 pl-20 hidden border-l-1 border-dashed border-black md:block"><ul><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Director Periodístico</h5><p class="text-xs line-h-lg font-bold">JUAN JOSÉ GARRIDO KOECHLIN</p></li><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Directores Fundadores</h5><p class="text-xs line-h-lg font-bold">Manuel Amunátegui [1839-1875] y</p><p class="text-xs line-h-lg font-bold">Alejandro Villota [1839-1861]</p></li><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Directores</h5><p class="text-xs line-h-lg font-bold">Francisco Miró Quesada Cantuarias</p><p class="text-xs line-h-lg font-bold">Luis Carranza [1875-1898]</p><p class="text-xs line-h-lg font-bold">José Antonio Miró Quesada [1875-1905]</p><p class="text-xs line-h-lg font-bold">Antonio Miró Quesada de la Guerra [1905-1935]</p><p class="text-xs line-h-lg font-bold">Aurelio Miró Quesada de la Guerra [1935-1950]</p><p class="text-xs line-h-lg font-bold">Luis Miró Quesada de la Guerra [1935-1974]</p><p class="text-xs line-h-lg font-bold">Óscar Miró Quesada de la Guerra [1980-1981]</p><p class="text-xs line-h-lg font-bold">Aurelio Miró Quesada Sosa [1980-1998]</p><p class="text-xs line-h-lg font-bold">Alejandro Miró Quesada Garland [1980-2011]</p><p class="text-xs line-h-lg font-bold">Alejandro Miró Quesada Cisneros [1999-2008]</p><p class="text-xs line-h-lg font-bold">Francisco Miró Quesada Rada [2008-2013]</p><p class="text-xs line-h-lg font-bold">Fritz Du Bois Freund [2013-2014]</p><p class="text-xs line-h-lg font-bold">Fernando Berckemeyer Olaechea [2014-2018]</p></li></ul></div><div class="flex-1 pr-20 pl-20 hidden border-l-1 border-dashed border-black lg:block"><ul class=""><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Suscripciones</h5><a class="text-sm line-h-md underline" href="mailto:suscriptores@comercio.com.pe">suscriptores@comercio.com.pe</a></li><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Publicidad</h5><a class="text-sm line-h-md underline" href="mailto:fonoavisos@comercio.com.pe">fonoavisos@comercio.com.pe</a></li><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Club El Comercio</h5><a class="text-sm line-h-md underline" href="mailto:clubelcomercio@comercio.com.pe">clubelcomercio@comercio.com.pe</a><br/><a class="text-sm line-h-md underline" href="https://elcomercio.pe/compromiso-autoregulacion-comercial.pdf" rel="noopener noreferrer" target="_blank">Compromiso de Autorregulación Comercial</a></li></ul><ul class=""><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="/terminos-y-condiciones">TÉRMINOS Y CONDICIONES DE USO</a></li><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="http://ecomedia.pe/libro/inicio/elcomercio/" rel="noopener noreferrer" target="_blank">LIBRO DE RECLAMACIONES</a></li><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="/oficinas-concesionarias" rel="noopener noref ...

# %%
# puede ser que una rtiqueta no se aunica
content.find_all('footer')
# Out:
# [<footer class=""><div class="flex flex-col p-30 bg-primary md:flex-row"><div class="flex-1 pr-20 pl-20 position-relative text-center md:text-left"><a class="footer__logo-container inline-block mb-15" href="/"><img alt="Logo de elcomercio" class="lazy w-full" data-src="/pf/resources/dist/elcomercio/images/logo.png?d=386" src=""/></a><address class="font-normal"><p class="text-sm line-h-md text-center md:text-left">Empresa Editora El Comercio</p><p class="text-sm line-h-md text-center md:text-left">Jr. Santa Rosa #300 Lima 1 Perú</p><p class="text-sm line-h-md text-center md:text-left">Copyright © Elcomercio.pe</p><p class="text-sm line-h-md text-center md:text-left">Grupo El Comercio - Todos los derechos reservados</p></address><div class="position-absolute bottom-0 hidden md:block"><img alt="Logo de Miembro del Grupo de Diarios de América" class="lazy mb-5" data-src="/pf/resources/assets/footer/logo-gda.png?d=386" src=""/><p class="text-sm line-h-sm">Miembro del Grupo de Diarios de América</p></div></div><div class="flex-1 pr-20 pl-20 hidden border-l-1 border-dashed border-black md:block"><ul><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Director Periodístico</h5><p class="text-xs line-h-lg font-bold">JUAN JOSÉ GARRIDO KOECHLIN</p></li><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Directores Fundadores</h5><p class="text-xs line-h-lg font-bold">Manuel Amunátegui [1839-1875] y</p><p class="text-xs line-h-lg font-bold">Alejandro Villota [1839-1861]</p></li><li class="mb-20"><h5 class="text-sm line-h-xs uppercase mb-5">Directores</h5><p class="text-xs line-h-lg font-bold">Francisco Miró Quesada Cantuarias</p><p class="text-xs line-h-lg font-bold">Luis Carranza [1875-1898]</p><p class="text-xs line-h-lg font-bold">José Antonio Miró Quesada [1875-1905]</p><p class="text-xs line-h-lg font-bold">Antonio Miró Quesada de la Guerra [1905-1935]</p><p class="text-xs line-h-lg font-bold">Aurelio Miró Quesada de la Guerra [1935-1950]</p><p class="text-xs line-h-lg font-bold">Luis Miró Quesada de la Guerra [1935-1974]</p><p class="text-xs line-h-lg font-bold">Óscar Miró Quesada de la Guerra [1980-1981]</p><p class="text-xs line-h-lg font-bold">Aurelio Miró Quesada Sosa [1980-1998]</p><p class="text-xs line-h-lg font-bold">Alejandro Miró Quesada Garland [1980-2011]</p><p class="text-xs line-h-lg font-bold">Alejandro Miró Quesada Cisneros [1999-2008]</p><p class="text-xs line-h-lg font-bold">Francisco Miró Quesada Rada [2008-2013]</p><p class="text-xs line-h-lg font-bold">Fritz Du Bois Freund [2013-2014]</p><p class="text-xs line-h-lg font-bold">Fernando Berckemeyer Olaechea [2014-2018]</p></li></ul></div><div class="flex-1 pr-20 pl-20 hidden border-l-1 border-dashed border-black lg:block"><ul class=""><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Suscripciones</h5><a class="text-sm line-h-md underline" href="mailto:suscriptores@comercio.com.pe">suscriptores@comercio.com.pe</a></li><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Publicidad</h5><a class="text-sm line-h-md underline" href="mailto:fonoavisos@comercio.com.pe">fonoavisos@comercio.com.pe</a></li><li class="mb-20"><h5 class="text-sm line-h-sm undefined">Club El Comercio</h5><a class="text-sm line-h-md underline" href="mailto:clubelcomercio@comercio.com.pe">clubelcomercio@comercio.com.pe</a><br/><a class="text-sm line-h-md underline" href="https://elcomercio.pe/compromiso-autoregulacion-comercial.pdf" rel="noopener noreferrer" target="_blank">Compromiso de Autorregulación Comercial</a></li></ul><ul class=""><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="/terminos-y-condiciones">TÉRMINOS Y CONDICIONES DE USO</a></li><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="http://ecomedia.pe/libro/inicio/elcomercio/" rel="noopener noreferrer" target="_blank">LIBRO DE RECLAMACIONES</a></li><li class="text-sm line-h-md mb-5 text-left"><a class="block" href="/oficinas-concesionarias" rel="noopener nore ...

# %%
content.find_all('article')

# %%
content.select('.featured-story') #es la clase

# %%
page =requests.get('https://www.tottus.com.pe/tottus/') ## el codigo 200 que nuestro pedido ha sido un exito
page.content # aqui sale el codigo html, para convertirla a uno mas amigable como el html
# Out:
# b'<!DOCTYPE html>\n    <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">\n    <!-- ServerName: mirto:10450 - orderId: 352192038 -->\n<head>\n  \t<script type="text/javascript" src="//www.tottus.com.pe/static/2520a//ext/jquery/jquery.min.js" ></script>\n\t\n    <script src="//assets.adobedtm.com/68ade2efaac6/c86087f44460/launch-48826154efae.min.js" async></script>\n\t<script lang="javascript">\n        var tottusConfig = {\n                displayContextSwitchingModal : false,\n                displayWarehouseContextSwitchingModal :false,\n                displayCheckPmmStockModal : false\n        };\n    </script>\n\n    <!-- Google Tag Manager -->\n        <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n        new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n        j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n        \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-57D8VR\');</script>\n        <!-- End Google Tag Manager -->\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\n    <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7; IE=EmulateIE9; IE=EmulateIE10" />\n    <meta name="google-site-verification" content="4zvA9A-BJaDYyXg4WxYhdRwkSiZM9SCmEb3RfHYMjSE" />\n    <style id="antiClickjack">body{display:none;}</style>\n    <script>\n        try {\n            document.execCommand(\'BackgroundImageCache\', false, true);\n        } catch (e) {\n        }\n        if (self === top) {\n            var antiClickjack = document.getElementById("antiClickjack");\n            antiClickjack.parentNode.removeChild(antiClickjack);\n        } else {\n            top.location = self.location;\n        }\n    </script>\n    \n    <meta name="robots" content="index,follow" />\n    <title>El Cyber Wow En Tottus Es Cyber Tottus</title>\n    <meta name="description" content="\xc2\xa1Preciazos! Supermercado y Electro. Vive la fiebre Cyber Wow 2019, aprovecha las ofertas que Cyber Tottus trae para ti. Mam\xc3\xa1 sabe: Tottus te da m\xc3\xa1s por menos." />\n  <meta name="keywords" content="supermercado"/>\n  <meta name="author" content="Tottus"/>\n  <link rel="schema.DC" href="http://www.purl.org/dc/elements/1.1/" />\n  <link rel="schema.DCTERMS" href="http://www.purl.org/dc/terms/" />\n  <link rel="schema.DCMITYPE" href="http://www.purl.org/dc/dcmitype/" />\n  <meta name="DC.title" content="El Cyber Wow En Tottus Es Cyber Tottus" />\n  <meta name="DC.creator" content="Tottus" />\n  <meta name="DC.subject" content="supermercado" />\n  <meta name="DC.description" content="\xc2\xa1Preciazos! Supermercado y Electro. Vive la fiebre Cyber Wow 2019, aprovecha las ofertas que Cyber Tottus trae para ti. Mam\xc3\xa1 sabe: Tottus te da m\xc3\xa1s por menos." />\n  <meta name="DC.publisher" content="Tottus" />\n  <meta name="DC.type" scheme="DCTERMS.DCMIType" content="Text" />\n  <meta name="DC.format" content="text/html" />\n  <meta name="DC.language" scheme="RFC1766" content="es" />\n  <meta name="DC.rights" content="/termsAndConditions" />\n  <meta name="DC.identifier" scheme="DCTERMS.URI" content="/" />\n<link rel="icon" href="//www.tottus.com.pe/static/2520a//favicon.ico" />\n    <!--[if lte IE 8]>\n          <link rel="stylesheet" href="//www.tottus.com.pe/static/2520a//css/ie.css" type="text/css" media="screen" title="ie.css" />\n      <![endif]-->\n\n    <link rel="stylesheet" href="//www.tottus.com.pe/static/2520a//css/site/store.css" type="text/css" media="screen" />\n    <link rel="stylesheet" href="//www.tottus.com.pe/static/2520a//css/site/store-pe.css" type="text/css" media="screen" />\n    <link rel="stylesheet" href="//www.tottus.com.pe/static/2520a//css/site/bootstrap-icon.css" type="text/css" media="screen ...

# %%
content = BeautifulSoup(page.content, 'html.parser') #parser es el traductor q identifica las etiquetas
content  # contiene todo el html

# %%
# find para buscar una unica etiqueta
# find_all busca todas las etiquetas
# select te busca por las clases y atributos, selector de css,

# %%
# primero no sabemos si es etiqueta o clase para sacar los precio
# si voy a extraer por clase utilizo select
content.select('.active-price')[0].select('.red')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-bb85d82ed12b> in <module>()
# ----> 1 content.select('.active-price')[0].select('.red')
#
# IndexError: list index out of range
