# %%
#############################################################################
################## -- Machine Learning Inmersion --##########################
####### Aprendizaje No Supervisado : Market Basquet Analysis ########
# Autor : André Chávez

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Instalar las librerias necesarias
#! pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Se trata de un conjunto de datos transnacionales que contiene todas las transacciones que se producen entre el 1 de diciembre 
# de 2010 y el 12 de septiembre de 2011 para un minorista en línea no registrado en el Reino Unido y con sede en el Reino Unido.
df = pd.read_excel('C:/Users/Andre Chavez/Desktop/Datos/OnlineRetail.xlsx')

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Podemos revisar los elementos del Set de Datos
df.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Limpiamos las descripciones, le quitamos espacios en blanco y los missings.
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
df.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom

# %%
# Podemos quitarle las transaciones con el formato que no necesitemos, además de filtrar personas no foco.
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
# Llevamos nuestra data transaccional o en filas.
# Estamos pivoteando las trx. Por ejemplo para el país de Francia.
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.shape
# Out:
# (392, 1563)

# %%
# Visualizamos sólo algunos productos o servicios
basket.iloc[:,[0,1,2,3,4,5,6, 7]].head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %%
# Convertimos la data a 0 o 1.
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
# Si deseamos podemos eliminar alguna descripción o columna.
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.head(100)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# 537468                            1                           0
# 537693                            0                           0
# 537897                            0                           0
# 537967                            0                           0
# 538008                            0                           0
# 538093                            0                           0
# 538196                            0                           0
# 539050                            0                           0
# ...

# %%
# Construyendo la frecuencia de las reglas
frequent_itemsets = apriori(basket_sets, min_support=0.10, use_colnames=True)

# %%
frequent_itemsets.head()
# Out:
#     support                     itemsets
# 0  0.102041  (ALARM CLOCK BAKELIKE PINK)
# 1  0.125000     (LUNCH BAG APPLE DESIGN)
# 2  0.153061    (LUNCH BAG RED RETROSPOT)
# 3  0.119898  (LUNCH BAG SPACEBOY DESIGN)
# 4  0.117347         (LUNCH BAG WOODLAND)

# %%
# Creando en las reglas
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                             antecedents                           consequents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)       (PLASTERS IN TIN CIRCUS PARADE)
# 2    (PLASTERS IN TIN WOODLAND ANIMALS)            (PLASTERS IN TIN SPACEBOY)
# 3            (PLASTERS IN TIN SPACEBOY)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 4         (SET/6 RED SPOTTY PAPER CUPS)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 5  (SET/20 RED RETROSPOT PAPER NAPKINS)         (SET/6 RED SPOTTY PAPER CUPS)
# 6       (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 7  (SET/20 RED RETROSPOT PAPER NAPKINS)       (SET/6 RED SPOTTY PAPER PLATES)
# 8         (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)
# 9       (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
# Podemos ya elegir o quedarnos con las reglas necesarias
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8)]
# Out:
#                        antecedents                           consequents  \
# 6  (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 8    (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)
# 9  (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 6            0.127551            0.132653  0.102041    0.800000  6.030769
# 8            0.137755            0.127551  0.122449    0.888889  6.968889
# 9            0.127551            0.137755  0.122449    0.960000  6.968889
#
#    leverage  conviction
# 6  0.085121    4.336735
# 8  0.104878    7.852041
# 9  0.104878   21.556122

# %%
# !! Ejercicio
